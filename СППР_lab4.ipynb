# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

iris_dataset = load_iris()
print("Ключі iris_dataset: \n{}".format(iris_dataset.keys()))
print("Назви цільових класів: {}".format(iris_dataset['target_names']))
print("Назви ознак: {}".format(iris_dataset['feature_names']))
# Out:
# Ключі iris_dataset:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename', 'data_module'])
# Назви цільових класів: ['setosa' 'versicolor' 'virginica']
# Назви ознак: ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    iris_dataset['data'], iris_dataset['target'], random_state=0)
print("Розмір X_train: {}".format(X_train.shape))
print("Розмір y_train: {}".format(y_train.shape))
print("Розмір X_test: {}".format(X_test.shape))
print("Розмір y_test: {}".format(y_test.shape))
# Out:
# Розмір X_train: (112, 4)
# Розмір y_train: (112,)
# Розмір X_test: (38, 4)
# Розмір y_test: (38,)

# %%
iris_dataframe = pd.DataFrame(X_train, columns=iris_dataset.feature_names)

pd.plotting.scatter_matrix(iris_dataframe, c=y_train, figsize=(15, 15),
                           marker='o', hist_kwds={'bins': 20}, s=60,
                           alpha=.8, cmap='viridis') 
plt.show()

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=1)

knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %%
score = knn.score(X_test, y_test)
print("Точність на тестовому наборі: {:.2f}".format(score))

X_new = np.array([[7.5, 3.0, 6.5, 2.1]])
prediction = knn.predict(X_new)

print("Передбачення: {}".format(prediction))
print("Спрогнозована назва виду: {}".format(iris_dataset['target_names'][prediction]))
# Out:
# Точність на тестовому наборі: 0.97
# Передбачення: [2]
# Спрогнозована назва виду: ['virginica']
